# %%
import os.path
# %pylab inline
from boris_analyse import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
build_dir_suffix = "build_clang"
build_dir = os.path.abspath(os.path.curdir + "/../../" + build_dir_suffix)
run_dir = os.path.abspath(os.path.curdir + "/../../run")

# %%
data = BorisData(build_dir=build_dir, nsteps=500, niter=20, nparticles=25)

# %%
plot_trajectories(data)
plot_analytics(data)
# Out:
# Initial Center of Mass:     9.9996	   -0.0012	    0.0001
# Last Center of Mass:       -7.8402	   -8.6055	   -9.6310
# Initial Energy:      219955.8065
# Final Energy:        222684.1400
# Final Drift:           2728.3334
# Final Residual:       3.0200e-14 (max: 4.2332e+01)

# %%
plot_trajectories(data, until=20)
plot_analytics(data, until=20, wo_drift=True)
# Out:
# Initial Center of Mass:     9.9996	   -0.0012	    0.0001
# Last Center of Mass:       12.5184	   -5.4318	   11.9518
# Initial Energy:      219955.8065
# Final Energy:        222684.1400
# Final Drift:           2728.3334
# Final Residual:       3.0200e-14 (max: 4.2332e+01)

# %%
plot_particle_meetup(data, get_meetup_after(data, 5), 10)
