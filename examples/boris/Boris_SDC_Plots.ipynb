# %%
import os.path
# %pylab inline
from boris_analyse import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
build_dir_suffix = "build_clang"
build_dir = os.path.abspath(os.path.curdir + "/../../" + build_dir_suffix)
run_dir = os.path.abspath(os.path.curdir + "/../../run")

# %%
data = BorisData(build_dir=build_dir, nsteps=500, niter=20, nparticles=25)

# %%
plot_trajectories(data)
plot_analytics(data)
# Out:
# Initial Center of Mass:     9.9996	   -0.0012	    0.0001
# Last Center of Mass:       -7.8402	   -8.6055	   -9.6310
# Initial Energy:           0.0000
# Final Energy:             0.0000
# Final Drift:           2728.3334
# Final Residual:       3.0200e-14 (max: 6.0400e-14)
# /home/t.klatt/projects/PFASST/examples/boris/boris_analyse.py:211: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(steprange, data.drift[start:ndisplay] / data.energy[start:ndisplay])

# %%
plot_trajectories(data, until=10)
plot_analytics(data, until=10, wo_drift=True)
# Out:
# Initial Center of Mass:     9.9996	   -0.0012	    0.0001
# Last Center of Mass:        7.5025	   -9.7370	   12.7448
# Initial Energy:           0.0000
# Final Energy:             0.0000
# Final Drift:           2728.3334
# Final Residual:       3.0200e-14 (max: 6.0400e-14)

# %%
plot_particle_meetup(data, 93, 10)
