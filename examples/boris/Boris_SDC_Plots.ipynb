# %%
import os.path
# %pylab inline
from boris_analyse import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
build_dir_suffix = "build_clang"
build_dir = os.path.abspath(os.path.curdir + "/../../" + build_dir_suffix)
run_dir = os.path.abspath(os.path.curdir + "/../../run")

# %%
data = BorisData(build_dir=build_dir, nsteps=500, niter=20, nparticles=5)

# %%
plot_trajectories(data)
plot_analytics(data)
# Out:
# Initial Center of Mass:     9.9995	   -0.0031	    0.0006
# Last Center of Mass:       -7.8403	   -8.6057	   -9.6317
# Initial Energy:       43981.2527
# Final Energy:         44063.6641
# Final Drift:             82.4114
# Final Residual:       2.5800e-14 (max: 3.9277e+01)

# %%
plot_trajectories(data, until=20)
plot_analytics(data, until=20, wo_drift=True)
# Out:
# Initial Center of Mass:     9.9995	   -0.0031	    0.0006
# Last Center of Mass:       12.5171	   -5.4331	   11.9520
# Initial Energy:       43981.2527
# Final Energy:         44063.6641
# Final Drift:             82.4114
# Final Residual:       2.5800e-14 (max: 3.9277e+01)

# %%
plot_particle_meetup(data, get_meetup_after(data, 5), 10)
